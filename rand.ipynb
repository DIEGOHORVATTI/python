# %%
import random

def aleatorio(x):
  print(x, ':', random.randrange(0, 100, 1))

x = 0
while x < 100:
  aleatorio(x)
  x+=1
# Out:
# 0 : 19
# 1 : 66
# 2 : 49
# 3 : 84
# 4 : 85
# 5 : 23
# 6 : 16
# 7 : 81
# 8 : 40
# 9 : 76
# 10 : 74
# 11 : 1
# 12 : 48
# 13 : 7
# 14 : 60
# 15 : 88
# 16 : 75
# 17 : 90
# 18 : 86
# 19 : 45
# 20 : 70
# 21 : 77
# 22 : 99
# 23 : 91
# 24 : 98
# 25 : 35
# 26 : 96
# 27 : 31
# 28 : 23
# 29 : 2
# 30 : 57
# 31 : 79
# 32 : 17
# 33 : 66
# 34 : 31
# 35 : 55
# 36 : 98
# 37 : 17
# 38 : 68
# 39 : 63
# 40 : 77
# 41 : 82
# 42 : 93
# 43 : 54
# 44 : 58
# 45 : 16
# 46 : 68
# 47 : 91
# 48 : 42
# 49 : 55
# 50 : 67
# 51 : 21
# 52 : 24
# 53 : 67
# 54 : 1
# 55 : 75
# 56 : 30
# 57 : 57
# 58 : 22
# 59 : 20
# 60 : 90
# 61 : 46
# 62 : 73
# 63 : 13
# 64 : 95
# 65 : 70
# 66 : 40
# 67 : 46
# 68 : 22
# 69 : 68
# 70 : 43
# 71 : 58
# 72 : 11
# 73 : 83
# 74 : 43
# 75 : 59
# 76 : 28
# 77 : 83
# 78 : 6
# 79 : 25
# 80 : 86
# 81 : 73
# 82 : 5
# 83 : 10
# 84 : 61
# 85 : 66
# 86 : 34
# 87 : 10
# 88 : 26
# 89 : 75
# 90 : 30
# 91 : 33
# 92 : 79
# 93 : 26
# 94 : 50
# 95 : 72
# 96 : 0
# 97 : 14
# 98 : 77
# 99 : 94
